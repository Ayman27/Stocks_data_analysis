# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tataelxsi_data = pd.read_excel('C:\\Users\\monst\\Desktop\\github projects\\Data sets\\tataelexsi_historical.xlsx', sheet_name = "Sheet1")

# %%
tataelxsi_data
# Out:
#           Date     Open     High      Low    Close   Volume
# 0   2019-04-22   952.30   973.15   950.05   956.40   454240
# 1   2019-04-23   961.70   961.70   948.20   950.60   275980
# 2   2019-04-24   954.00   957.85   926.25   929.75  1627535
# 3   2019-04-25   930.00   934.40   923.00   927.30   717900
# 4   2019-04-26   929.90   939.95   917.40   922.45   538879
# ..         ...      ...      ...      ...      ...      ...
# 733 2022-04-07  8907.00  8938.25  8703.00  8747.80   343816
# 734 2022-04-08  8791.55  9088.00  8621.00  8685.20   778818
# 735 2022-04-11  8723.00  8820.00  8620.00  8711.15   420571
# 736 2022-04-12  8740.00  8741.00  8326.40  8409.25   599014
# 737 2022-04-13  8470.00  8635.00  8350.00  8383.80   397311
#
# [738 rows x 6 columns]

# %%
tataelxsi_data.head()
# Out:
#         Date   Open    High     Low   Close   Volume
# 0 2019-04-22  952.3  973.15  950.05  956.40   454240
# 1 2019-04-23  961.7  961.70  948.20  950.60   275980
# 2 2019-04-24  954.0  957.85  926.25  929.75  1627535
# 3 2019-04-25  930.0  934.40  923.00  927.30   717900
# 4 2019-04-26  929.9  939.95  917.40  922.45   538879

# %%
tataelxsi_data.tail()
# Out:
#           Date     Open     High     Low    Close  Volume
# 733 2022-04-07  8907.00  8938.25  8703.0  8747.80  343816
# 734 2022-04-08  8791.55  9088.00  8621.0  8685.20  778818
# 735 2022-04-11  8723.00  8820.00  8620.0  8711.15  420571
# 736 2022-04-12  8740.00  8741.00  8326.4  8409.25  599014
# 737 2022-04-13  8470.00  8635.00  8350.0  8383.80  397311

# %%
tataelxsi_data.shape
# Out:
# (738, 6)

# %%
tataelxsi_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 738 entries, 0 to 737
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    738 non-null    datetime64[ns]
#  1   Open    738 non-null    float64
#  2   High    738 non-null    float64
#  3   Low     738 non-null    float64
#  4   Close   738 non-null    float64
#  5   Volume  738 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 34.7 KB

# %%
tataelxsi_data.describe()
# Out:
#               Open         High          Low        Close        Volume
# count   738.000000   738.000000   738.000000   738.000000  7.380000e+02
# mean   2641.952100  2695.479946  2592.634824  2641.550542  6.061728e+05
# std    2276.317009  2324.166668  2231.633789  2274.990962  7.414633e+05
# min     540.000000   569.000000   499.950000   544.400000  5.969800e+04
# 25%     855.137500   867.225000   844.012500   854.750000  2.456608e+05
# 50%    1482.500000  1510.700000  1439.525000  1470.075000  4.015030e+05
# 75%    4259.750000  4295.712500  4194.175000  4242.462500  7.053065e+05
# max    9090.000000  9420.000000  8931.500000  9035.500000  9.825204e+06

# %%
tataelxsi_data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
tataelxsi_data.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(20,8))
ax.plot(tataelxsi_data['Date'], tataelxsi_data['Close'])
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
ax.set_xlabel('Date', fontsize='11')
ax.set_ylabel('Price in INR', fontsize='11')
plt.title('Tataelxsi Stock Prices')
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,8))
ax.bar(tataelxsi_data['Date'], tataelxsi_data['Volume'])
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
ax.set_xlabel('Date', fontsize='11')
ax.set_ylabel('Volumes', fontsize='11')
plt.title('Volume Trends', fontsize='20')
plt.grid()
plt.show()

# %%
tataelxsi_data['Market Cap'] = tataelxsi_data['Open']*tataelxsi_data['Volume']

# %%
fig, ax = plt.subplots(figsize=(20,8))
ax.plot(tataelxsi_data['Date'], tataelxsi_data['Market Cap'], color='orange')
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
ax.set_xlabel('Date', fontsize='11')
ax.set_ylabel('Market Cap', fontsize='11')
plt.title('Market Cap')
plt.grid()
plt.show()

# %%
tataelxsi_data.iloc[tataelxsi_data['Market Cap'].argmax()]
# Out:
# Date          2022-03-28 00:00:00
# Open                       8465.0
# High                       9160.0
# Low                        8180.0
# Close                      9035.5
# Volume                    3109546
# Market Cap          26322306890.0
# Name: 725, dtype: object

# %%
tataelxsi_data['vol'] = (tataelxsi_data['Close']/tataelxsi_data['Close'].shift(1)) - 1

# %%
fig, ax = plt.subplots(figsize=(20,8))
ax.plot(tataelxsi_data['Date'], tataelxsi_data['vol'], color='purple')
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
plt.title('Volatility')
plt.grid()
plt.show()

# %%
tataelxsi_data['vol'].hist(bins=100, color='orange');

# %%
tataelxsi_data['Cumulative Return'] = (1 + tataelxsi_data['vol']).cumprod()

# %%
fig, ax = plt.subplots(figsize=(20,8))
ax.plot(tataelxsi_data['Date'], tataelxsi_data['Cumulative Return'], color='green')
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
ax.set_xlabel('Date', fontsize='11')
ax.set_ylabel('Cumulative Return', fontsize='11')
plt.title('Cumulative Return')
plt.grid()
plt.show()

# %%
tataelxsi_data.iloc[tataelxsi_data['Cumulative Return'].argmax()]
# Out:
# Date                 2022-03-28 00:00:00
# Open                              8465.0
# High                              9160.0
# Low                               8180.0
# Close                             9035.5
# Volume                           3109546
# Market Cap                 26322306890.0
# vol                             0.070785
# Cumulative Return               9.447407
# Name: 725, dtype: object
