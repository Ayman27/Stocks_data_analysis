# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
maninfra_data = pd.read_excel('C:\\Users\\monst\\Desktop\\github projects\\Data sets\\maninfra_dataset.xlsx')

# %%
maninfra_data
# Out:
#           Date    Open    High     Low   Close   Volume  Unnamed: 6
# 0   2019-04-22   25.03   25.27   24.33   24.40    66539         NaN
# 1   2019-04-23   24.40   24.93   24.20   24.37    49318         NaN
# 2   2019-04-24   24.53   25.10   24.33   24.83    78127         NaN
# 3   2019-04-25   25.17   25.17   24.33   24.53    50969         NaN
# 4   2019-04-26   24.60   24.73   24.00   24.13    47694         NaN
# ..         ...     ...     ...     ...     ...      ...         ...
# 735 2022-04-11  114.95  117.10  113.75  116.20   809087         NaN
# 736 2022-04-12  115.05  119.90  112.00  119.05  1416730         NaN
# 737 2022-04-13  121.40  124.70  118.10  119.25  2784519         NaN
# 738 2022-04-18  117.75  121.95  116.00  116.90   981656         NaN
# 739 2022-04-19  117.50  118.85  107.00  110.45   770946         NaN
#
# [740 rows x 7 columns]

# %%
maninfra_data.head()
# Out:
#         Date   Open   High    Low  Close  Volume  Unnamed: 6
# 0 2019-04-22  25.03  25.27  24.33  24.40   66539         NaN
# 1 2019-04-23  24.40  24.93  24.20  24.37   49318         NaN
# 2 2019-04-24  24.53  25.10  24.33  24.83   78127         NaN
# 3 2019-04-25  25.17  25.17  24.33  24.53   50969         NaN
# 4 2019-04-26  24.60  24.73  24.00  24.13   47694         NaN

# %%
maninfra_data.tail()
# Out:
#           Date    Open    High     Low   Close   Volume  Unnamed: 6
# 735 2022-04-11  114.95  117.10  113.75  116.20   809087         NaN
# 736 2022-04-12  115.05  119.90  112.00  119.05  1416730         NaN
# 737 2022-04-13  121.40  124.70  118.10  119.25  2784519         NaN
# 738 2022-04-18  117.75  121.95  116.00  116.90   981656         NaN
# 739 2022-04-19  117.50  118.85  107.00  110.45   770946         NaN

# %%
maninfra_data.shape
# Out:
# (740, 7)

# %%
maninfra_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        740 non-null    datetime64[ns]
#  1   Open        740 non-null    float64
#  2   High        740 non-null    float64
#  3   Low         740 non-null    float64
#  4   Close       740 non-null    float64
#  5   Volume      740 non-null    int64
#  6   Unnamed: 6  0 non-null      float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 40.6 KB

# %%
maninfra_data.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  740.000000  740.000000  740.000000  740.000000  7.400000e+02
# mean    36.258189   37.287068   35.241176   36.229284  8.019512e+05
# std     32.161274   33.032798   31.319059   32.212603  1.275588e+06
# min     10.000000   10.530000    9.270000   10.030000  2.073900e+04
# 25%     15.560000   16.330000   15.070000   15.660000  1.223788e+05
# 50%     21.750000   22.135000   20.870000   21.435000  3.372210e+05
# 75%     41.685000   42.310000   40.122500   41.540000  8.936760e+05
# max    129.600000  131.100000  123.900000  128.550000  1.254202e+07
#
#        Unnamed: 6
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
maninfra_data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Unnamed: 6'], dtype='object')

# %%
maninfra_data.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Unnamed: 6    740
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(20,8))
ax.plot(maninfra_data['Date'], maninfra_data['Close'])
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
ax.set_xlabel('Date', fontsize='11')
ax.set_ylabel('Price in INR', fontsize='11')
plt.title('Maninfra Stock Prices')
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,8))
ax.bar(maninfra_data['Date'], maninfra_data['Volume'])
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
ax.set_xlabel('Date', fontsize='11')
ax.set_ylabel('Volumes', fontsize='11')
plt.title('Volume Trends', fontsize='20')
plt.grid()
plt.show()

# %%
maninfra_data['Market Cap'] = maninfra_data['Open']*maninfra_data['Volume']

# %%
maninfra_data.head()
# Out:
#         Date   Open   High    Low  Close  Volume  Unnamed: 6  Market Cap
# 0 2019-04-22  25.03  25.27  24.33  24.40   66539         NaN  1665471.17
# 1 2019-04-23  24.40  24.93  24.20  24.37   49318         NaN  1203359.20
# 2 2019-04-24  24.53  25.10  24.33  24.83   78127         NaN  1916455.31
# 3 2019-04-25  25.17  25.17  24.33  24.53   50969         NaN  1282889.73
# 4 2019-04-26  24.60  24.73  24.00  24.13   47694         NaN  1173272.40

# %%
fig, ax = plt.subplots(figsize=(20,8))
ax.plot(maninfra_data['Date'], maninfra_data['Market Cap'], color='orange')
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
ax.set_xlabel('Date', fontsize='11')
ax.set_ylabel('Market Cap', fontsize='11')
plt.title('Market Cap')
plt.grid()
plt.show()

# %%
maninfra_data.iloc[maninfra_data['Market Cap'].argmax()]
# Out:
# Date          2021-11-17 00:00:00
# Open                        96.85
# High                        107.6
# Low                          93.1
# Close                       104.5
# Volume                    6280074
# Unnamed: 6                    NaN
# Market Cap            608225166.9
# Name: 636, dtype: object

# %%
maninfra_data['vol'] = (maninfra_data['Close']/maninfra_data['Close'].shift(1)) - 1

# %%
fig, ax = plt.subplots(figsize=(20,8))
ax.plot(maninfra_data['Date'], maninfra_data['vol'], color='purple')
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
plt.title('Volatility')
plt.grid()
plt.show()

# %%
maninfra_data['vol'].hist(bins=100, color='orange');

# %%
maninfra_data['Cumulative Return'] = (1 + maninfra_data['vol']).cumprod()

# %%
fig, ax = plt.subplots(figsize=(20,8))
ax.plot(maninfra_data['Date'], maninfra_data['Cumulative Return'], color='green')
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
ax.set_xlabel('Date', fontsize='11')
ax.set_ylabel('Cumulative Return', fontsize='11')
plt.title('Cumulative Return')
plt.grid()
plt.show()

# %%
maninfra_data.iloc[maninfra_data['Cumulative Return'].argmax()]
# Out:
# Date                 2022-01-10 00:00:00
# Open                               120.0
# High                               131.0
# Low                                118.0
# Close                             128.55
# Volume                           4817301
# Unnamed: 6                           NaN
# Market Cap                   578076120.0
# vol                             0.094974
# Cumulative Return               5.268443
# Name: 673, dtype: object
